# %%
from retinaface import RetinaFace
import cv2

# %%
resp = RetinaFace.detect_faces("test.jpg")
resp
# Out:
# Directory  C:\Users\bobla /.deepface created
# Directory  C:\Users\bobla /.deepface/weights created
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: C:\Users\bobla\.deepface\weights\retinaface.h5
# 100%|██████████| 119M/119M [00:12<00:00, 9.23MB/s]
# {'face_1': {'score': 0.9983367919921875,
#   'facial_area': [410, 519, 492, 630],
#   'landmarks': {'right_eye': [424.94937, 574.7037],
#    'left_eye': [441.58502, 572.807],
#    'nose': [426.5902, 598.7659],
#    'mouth_right': [445.14426, 607.5491],
#    'mouth_left': [458.18942, 604.4587]}},
#  'face_2': {'score': 0.9973416924476624,
#   'facial_area': [952, 712, 979, 745],
#   'landmarks': {'right_eye': [958.7058, 725.2453],
#    'left_eye': [971.5894, 725.0986],
#    'nose': [964.77594, 730.7779],
#    'mouth_right': [959.88416, 737.8299],
# ...

# %%
# Load the image
image_path = 'test.jpg'
img = cv2.imread(image_path)

# Detect faces
faces = RetinaFace.detect_faces(image_path)
if type(faces) == dict:
    for face in faces.values():
        # Get the coordinates of the bounding box
        p0, p1, p2, p3 = face['facial_area']

        # Draw a rectangle around the detected face
        cv2.rectangle(img, (p2, p3), (p0, p1), (0, 255, 0), 2)  # Green rectangle

        # If you also want to show the facial landmarks:
        # for landmark in face['landmarks']:
        #     cv2.circle(img, tuple(landmark), 2, (0, 0, 255), 2)  # Red dot

# Show the image with detected faces
cv2.imshow('Detected Faces', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
??RetinaFace.extract_faces
# Out:
# Signature:
# RetinaFace.extract_faces(
#     img_path,
#     threshold=0.9,
#     model=None,
#     align=True,
#     allow_upscaling=True,
# )
# Docstring: <no docstring>
# Source:
# def extract_faces(img_path, threshold=0.9, model = None, align = True, allow_upscaling = True):
#
#     resp = []
#
#     #---------------------------
#
#     img = get_image(img_path)
#
#     #---------------------------
#
#     obj = detect_faces(img_path = img, threshold = threshold, model = model, allow_upscaling = allow_upscaling)
#
#     if type(obj) == dict:
#         for key in obj:
#             identity = obj[key]
#
#             facial_area = identity["facial_area"]
#             facial_img = img[facial_area[1]: facial_area[3], facial_area[0]: facial_area[2]]
#
#             if align == True:
#                 landmarks = identity["landmarks"]
#                 left_eye = landmarks["left_eye"]
#                 right_eye = landmarks["right_eye"]
#                 nose = landmarks["nose"]
# ...
